# %% [markdown]
# <a href="https://colab.research.google.com/github/pravanjang/GenAI-Training-Colab/blob/main/GenAI_Connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Read all the keys. This notebook is running on Colab, so, current code is to read from secrets. If running locally read it from .envs.

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
GROK_API_KEY = userdata.get('GROK_API_KEY')
ANTHROPIC_API_KEY = userdata.get('ANTHROPIC_API_KEY')

# %% [markdown]
# Install the libraries. This is required if running locally. Not required on colab

# %%
# !pip install openai

# %% [markdown]
# Frame the message

# %%
message = "What is the date today?"

messages = [{"role": "user", "content": message}]

# %% [markdown]
# Connect to chatgpr using openapi library

# %%
from openai import OpenAI

openai = OpenAI(api_key=OPENAI_API_KEY)

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
